# %% [markdown]
# # The first page of coursera parsed and saved in a csv file
#
# ## Includes:
# - Course Title
# - Course Organization
# - Course URL
# - Course Certificate Type
# - Course Rating
# - Course Difficulty
# - Course Students Enrolled
# - Course Image URL
# - Image name

# %%
from bs4 import BeautifulSoup
import requests
response = requests.get("https://www.coursera.org/courses")
html_soup = BeautifulSoup(response.content, 'html.parser')
url = html_soup.find_all(href=True)

# %%
course_title = []
course_organization = []
course_URL =[]
course_Certificate_type = []
course_rating = []
course_difficulty = []
course_students_enrolled = []
course_image_URL = []
course_image_name=[]

# %%
#to scrape all pages loop the variable at page =1 as page =i
url = "https://www.coursera.org/courses?page=1&index=prod_all_products_term_optimization"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')


for j in range(0,10):
    ct = soup.find_all('h2', class_ ="color-primary-text card-title headline-1-text")[j].get_text()
    course_title.append(ct)
    co = soup.find_all('span', class_ = 'partner-name m-b-1s')[j].get_text()
    course_organization.append(co)
    cu= soup.find_all("a", class_='rc-DesktopSearchCard anchor-wrapper')[j]
    course_URL.append("https://www.coursera.org"+ cu.get('href'))
    cc= soup.find_all('div', class_='_jen3vs _1d8rgfy3')[j].get_text()
    course_Certificate_type.append(cc)
    cr=soup.find_all('span', class_ = 'ratings-text')[j]
    course_rating.append(cr)
    cd= soup.find_all('span',class_='difficulty')[j].get_text()
    course_difficulty.append(cd)
    ce= soup.find_all('span',class_='enrollment-number')[j].get_text()
    course_students_enrolled.append(ce)
    x_div = soup.find_all('img', class_ ="product-photo")[j]
    course_image_URL.append(x_div.get('src'))
    course_image_name.append(x_div.get('alt'))

# %%
import pandas as pd
courses_df = pd.DataFrame({'course_title': course_title,
                           'course_URL':course_URL,
                          'course_organization': course_organization,
                          'course_Certificate_type': course_Certificate_type,
                          'course_rating':course_rating,
                           'course_difficulty':course_difficulty,
                           'course_students_enrolled':course_students_enrolled,
                            'course_icon':course_image_URL,
                          'image_name':course_image_name})

# courses_df = courses_df.sort_values('course_title')

courses_df.to_csv('Coursera_Courses_test.csv')

# %% [markdown]
# # Using Functions

# %%
course_title = []
course_organization = []
course_URL =[]
course_Certificate_type = []
course_rating = []
course_difficulty = []
course_students_enrolled = []
course_image_URL = []
course_image_name=[]

# %%
def auto_scrape(j,html_tag,class_tag,course_item):
    bsoup = soup.find_all(html_tag, class_ = class_tag)[j].get_text()
    course_item.append(bsoup)
def auto_scrape_imgURL(j,html_tag,class_tag,course_url_item,course_url_name):
    x_div = soup.find_all('img', class_ ="product-photo")[j]
    course_url_item.append(x_div.get('src'))
    course_url_name.append(x_div.get('alt'))
def auto_scrape_URL(j,html_tag,class_tag,course_item):
    cu= soup.find_all("a", class_='rc-DesktopSearchCard anchor-wrapper')[j]
    course_URL.append("https:/www.coursera.org"+ cu.get('href'))

# %%
for j in range(0,10):
    auto_scrape(j,'h2',"color-primary-text card-title headline-1-text",course_title)
    auto_scrape(j,'span', 'partner-name m-b-1s',course_organization)
    auto_scrape_URL(j,"a",'rc-DesktopSearchCard anchor-wrapper',course_URL)
    auto_scrape(j,'div','_jen3vs _1d8rgfy3',course_Certificate_type)
    auto_scrape(j,'span', 'ratings-text',course_rating)
    auto_scrape(j,'span','difficulty',course_difficulty)
    auto_scrape(j,'span','enrollment-number',course_students_enrolled)
    auto_scrape_imgURL(j,'img', "product-photo",course_image_URL,course_image_name)

# %%
import pandas as pd
coursesf_df = pd.DataFrame({'course_title': course_title,
                           'course_URL':course_URL,
                          'course_organization': course_organization,
                          'course_Certificate_type': course_Certificate_type,
                          'course_rating':course_rating,
                           'course_difficulty':course_difficulty,
                           'course_students_enrolled':course_students_enrolled,
                            'course_icon':course_image_URL,
                          'image_name':course_image_name})

# courses_df = courses_df.sort_values('course_title')

coursesf_df.to_csv('Coursera_Courses_test_function.csv')

# %% [markdown]
# END OF FILE

# %% [markdown]
# # TESTING FOR NONE OBJECTS IN THE COMPLETE CATALOG

# %%
df = pd.DataFrame()

# %%
# course title
count1=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    for j in range(0,10):
        ct = soup.find_all('h2', class_ ="color-primary-text card-title headline-1-text")[j].get_text()
        count1.append(ct)
    print(len(count1),end="\t|\t")
df['course_title'] = count1
# Out:
# 1 10	|	2 20	|	3 30	|	4 40	|	5 50	|	6 60	|	7 70	|	8 80	|	9 90	|	10 100	|	11 110	|	12 120	|	13 130	|	14 140	|	15 150	|	16 160	|	17 170	|	18 180	|	19 190	|	20 200	|	21 210	|	22 220	|	23 230	|	24 240	|	25 250	|	26 260	|	27 270	|	28 280	|	29 290	|	30 300	|	31 310	|	32 320	|	33 330	|	34 340	|	35 350	|	36 360	|	37 370	|	38 380	|	39 390	|	40 400	|	41 410	|	42 420	|	43 430	|	44 440	|	45 450	|	46 460	|	47 470	|	48 480	|	49 490	|	50 500	|	51 510	|	52 520	|	53 530	|	54 540	|	55 550	|	56 560	|	57 570	|	58 580	|	59 590	|	60 600	|	61 610	|	62 620	|	63 630	|	64 640	|	65 650	|	66 660	|	67 670	|	68 680	|	69 690	|	70 700	|	71 710	|	72 720	|	73 730	|	74 740	|	75 750	|	76 760	|	77 770	|	78 780	|	79 790	|	80 800	|	81 810	|	82 820	|	83 830	|	84 840	|	85 850	|	86 860	|	87 870	|	88 880	|	89 890	|	90 900	|	91 910	|	92 920	|	93 930	|	94 940	|	95 950	|	96 960	|	97 970	|	98 980	|	99 990	|

# %%
#course URL
count=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    for j in range(0,10):
        cu= soup.find_all("a", class_='rc-DesktopSearchCard anchor-wrapper')[j]
        count.append("https://www.coursera.org"+ cu.get('href'))
    print(len(count),end="\t|\t")
df['course_URL']=count
# Out:
# 1 10	|	2 20	|	3 30	|	4 40	|	5 50	|	6 60	|	7 70	|	8 80	|	9 90	|	10 100	|	11 110	|	12 120	|	13 130	|	14 140	|	15 150	|	16 160	|	17 170	|	18 180	|	19 190	|	20 200	|	21 210	|	22 220	|	23 230	|	24 240	|	25 250	|	26 260	|	27 270	|	28 280	|	29 290	|	30 300	|	31 310	|	32 320	|	33 330	|	34 340	|	35 350	|	36 360	|	37 370	|	38 380	|	39 390	|	40 400	|	41 410	|	42 420	|	43 430	|	44 440	|	45 450	|	46 460	|	47 470	|	48 480	|	49 490	|	50 500	|	51 510	|	52 520	|	53 530	|	54 540	|	55 550	|	56 560	|	57 570	|	58 580	|	59 590	|	60 600	|	61 610	|	62 620	|	63 630	|	64 640	|	65 650	|	66 660	|	67 670	|	68 680	|	69 690	|	70 700	|	71 710	|	72 720	|	73 730	|	74 740	|	75 750	|	76 760	|	77 770	|	78 780	|	79 790	|	80 800	|	81 810	|	82 820	|	83 830	|	84 840	|	85 850	|	86 860	|	87 870	|	88 880	|	89 890	|	90 900	|	91 910	|	92 920	|	93 930	|	94 940	|	95 950	|	96 960	|	97 970	|	98 980	|	99 990	|

# %%
# course organisation
count=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    for j in range(0,10):
        co = soup.find_all('span', class_ = 'partner-name m-b-1s')[j].get_text()
        count.append(co)
    print(len(count),end="\t|\t")       
#
# Out:
# 1 10	|	2 20	|	3 30	|	4 40	|	5 50	|	6 60	|	7 70	|	8 80	|	9 90	|	10 100	|	11 110	|	12 120	|	13 130	|	14 140	|	15 150	|	16 160	|	17 170	|	18 180	|	19 190	|	20 200	|	21 210	|	22 220	|	23 230	|	24 240	|	25 250	|	26 260	|	27 270	|	28 280	|	29 290	|	30 300	|	31 310	|	32 320	|	33 330	|	34 340	|	35 350	|	36 360	|	37 370	|	38 380	|	39 390	|	40 400	|	41 410	|	42 420	|	43 430	|	44 440	|	45 450	|	46 460	|	47 470	|	48 480	|	49 490	|	50 500	|	51 510	|	52 520	|	53 530	|	54 540	|	55 550	|	56 560	|	57 570	|	58 580	|	59 590	|	60 600	|	61 610	|	62 620	|	63 630	|	64 640	|	65 650	|	66 660	|	67 670	|	68 680	|	69 690	|	70 700	|	71 710	|	72 720	|	73 730	|	74 740	|	75 750	|	76 760	|	77 770	|	78 780	|	79 790	|	80 800	|	81 810	|	82 820	|	83 830	|	84 840	|	85 850	|	86 860	|	87 870	|	88 880	|	89 890	|	90 900	|	91 910	|	92 920	|	93 930	|	94 940	|	95 950	|	96 960	|	97 970	|	98 980	|	99 990	|

# %%
df['course_organization']= count

# %%
# course certificate type
count=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    for j in range(0,10):
        cc= soup.find_all('div', class_='_jen3vs _1d8rgfy3')[j].get_text()
        count.append(cc)
    print(len(count),end="\t|\t")
# Out:
# 1 10	|	2 20	|	3 30	|	4 40	|	5 50	|	6 60	|	7 70	|	8 80	|	9 90	|	10 100	|	11 110	|	12 120	|	13 130	|	14 140	|	15 150	|	16 160	|	17 170	|	18 180	|	19 190	|	20 200	|	21 210	|	22 220	|	23 230	|	24 240	|	25 250	|	26 260	|	27 270	|	28 280	|	29 290	|	30 300	|	31 310	|	32 320	|	33 330	|	34 340	|	35 350	|	36 360	|	37 370	|	38 380	|	39 390	|	40 400	|	41 410	|	42 420	|	43 430	|	44 440	|	45 450	|	46 460	|	47 470	|	48 480	|	49 490	|	50 500	|	51 510	|	52 520	|	53 530	|	54 540	|	55 550	|	56 560	|	57 570	|	58 580	|	59 590	|	60 600	|	61 610	|	62 620	|	63 630	|	64 640	|	65 650	|	66 660	|	67 670	|	68 680	|	69 690	|	70 700	|	71 710	|	72 720	|	73 730	|	74 740	|	75 750	|	76 760	|	77 770	|	78 780	|	79 790	|	80 800	|	81 810	|	82 820	|	83 830	|	84 840	|	85 850	|	86 860	|	87 870	|	88 880	|	89 890	|	90 900	|	91 910	|	92 920	|	93 930	|	94 940	|	95 950	|	96 960	|	97 970	|	98 980	|	99 990	|

# %%
df['course_certificate_type']= count

# %%
# course-rating
count=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    for j in range(0,10):
        cr=soup.find_all('div', class_ = "rating-enroll-wrapper")[j]
        x_div=cr.find('span',class_="ratings-text")
        if x_div is None:
            print("None",end=' ')
            count.append("None")
        else:        
            print(x_div.get_text(),end=' ')
            count.append(x_div.get_text())
    print(len(count),end="  |  ")
# Out:
# 1 4.8 4.6 4.6 4.8 4.8 4.7 4.9 4.7 4.7 4.8 10  |  2 4.6 4.6 4.7 4.9 4.8 4.7 4.7 4.7 4.7 4.5 20  |  3 4.9 4.6 4.6 4.5 4.6 4.6 4.7 4.6 4.7 4.5 30  |  4 4.5 4.7 4.7 4.7 4.7 4.7 4.6 4.9 4.7 4.7 40  |  5 4.6 4.8 4.5 4.5 4.7 4.6 4.6 4.8 4.7 4.7 50  |  6 4.7 4.6 4.6 4.7 4.8 4.6 4.8 4.6 4.9 4.6 60  |  7 4.7 4.6 4.7 4.7 4.8 4.8 4.8 4.9 4.7 4.5 70  |  8 4.6 4.8 4.5 4.8 4.7 4.7 4.7 4.7 4.7 4.9 80  |  9 4.6 4.7 4.7 4.6 4.8 4.7 4.8 4.8 4.6 4.8 90  |  10 4.7 4.7 4.7 4.6 4.6 4.7 4.6 4.4 4.6 4.7 100  |  11 4.7 4.9 4.8 4.9 4.7 4.5 4.6 4.8 4.8 4.7 110  |  12 4.8 4.7 4.8 4.8 4.9 4.8 4.7 4.7 4.7 4.9 120  |  13 4.7 4.8 4.7 4.7 4.5 4.7 4.7 4.6 4.7 4.5 130  |  14 4.8 4.8 4.8 4.7 4.7 4.7 4.9 4.6 4.7 4.7 140  |  15 4.5 4.8 4.7 4.7 4.7 4.7 4.5 4.8 4.6 4.8 150  |  16 4.9 4.7 4.5 4.6 4.9 4.7 4.5 4.7 4.9 4.7 160  |  17 4.7 4.7 4.8 4.3 4.7 4.7 4.5 4.7 4.6 4.8 170  |  18 4.7 4.8 4.7 4.7 4.7 4.8 4.7 4.6 4.8 4.7 180  |  19 4.7 4.6 4.5 4.7 4.8 4.6 4.7 4.7 4.6 4.8 190  |  20 4.6 4.4 4.8 3.9 4.4 4.7 4.5 4.5 4.7 4.6 200  |  21 4.7 4.8 4.8 4.7 4.7 4.6 4.6 4.5 4.6 4.7 210  |  22 4.7 4.5 4.7 4.5 4.6 4.8 4.7 4.8 4.7 4.8 220  |  23 4.7 4.9 4.9 4.8 4.6 4.8 4.6 4.7 4.9 4.8 230  |  24 4.8 4.6 4.8 4.8 4.6 4.7 4.6 4.5 4.9 4.8 240  |  25 4.8 4.7 4.6 4.4 4.8 4.7 4.8 4.5 4.6 4.7 250  |  26 4.8 4.9 4.6 4.7 4.7 4.7 4.7 4.9 4.8 4.7 260  |  27 4.8 4.8 4.7 4.5 4.7 4.8 4.8 4.3 4.8 4.8 270  |  28 4.6 4.7 4.6 4.8 4.9 4.3 4.8 4.6 4.7 4.8 280  |  29 4.5 4.8 4.6 4.5 4.7 4.7 4.6 4.9 None 4.8 290  |  30 4.7 4.8 4.7 4.7 4.8 4.4 4.6 4.8 4.8 4.5 300  |  31 4.7 4.7 4.7 4.8 4.7 4.7 4.3 4.5 4.8 4.7 310  |  32 4.8 4.8 4.8 4.8 4.8 4.5 4.2 4.8 4.8 4.7 320  |  33 4.8 4.6 4.9 4.7 4.6 4.7 4.5 4.7 4.8 4.8 330  |  34 4.8 4.7 4.6 4.4 4.6 4.7 4.8 4.6 4.6 4.8 340  |  35 4.7 4.8 4.7 4.5 4.7 4.6 4.8 4.5 4.7 4.7 350  |  36 4.8 4.7 4.8 4.7 4.8 4.8 4.8 4.9 4.8 4.5 360  |  37 4.8 4.7 4.5 4.5 4.7 4.7 4.9 4.7 4.9 4.8 370  |  38 4.4 4.7 4.8 4.5 4.7 4.7 4.5 4.7 4.8 4.7 380  |  39 4.5 4.6 4.6 4.8 4.7 None 4.3 4.7 4.5 4.8 390  |  40 4.5 4.9 4.6 4.7 4.6 4.6 4.8 4.7 4.8 4.8 400  |  41 4.7 4.1 4.9 4.4 4.8 4.7 4.3 4.5 4.7 4.7 410  |  42 4.7 3.9 4.8 4.8 4.7 4.3 4.7 4.8 4.7 4.6 420  |  43 4.7 4.4 4.6 4.5 4.6 4.7 4.8 4.8 4.8 4.8 430  |  44 4.8 4.6 4.7 4.8 4.8 4.7 4.7 4.6 3.8 4.7 440  |  45 4.8 4.7 4.7 4.8 4.8 4.8 4.8 4.8 4.5 4.8 450  |  46 4.6 4.7 4.7 4.8 4.7 4.8 3.7 4.7 4.7 4.8 460  |  47 4.7 4.7 4.8 4.5 4.8 4.6 4.9 4.6 4.8 4.8 470  |  48 4.7 4.5 4.8 4.7 4.6 4.8 4.8 4.8 4.8 4.8 480  |  49 4.3 4.7 4.7 4.9 4.3 4.8 4.6 4.9 4.6 4.5 490  |  50 4.8 4.9 4.9 4.8 4.8 4.6 4.6 4.8 4.6 4.9 500  |  51 4.7 4.7 4.5 4.6 4.6 4.9 4.7 4.9 4.8 4.8 510  |  52 4.6 4.7 4.7 4.5 4.7 4.8 4.5 4.4 4.7 4.7 520  |  53 5 4.8 4.7 4.8 4.7 4.7 4.8 4.8 4.6 4.8 530  |  54 4.5 4.7 4.8 4.6 4.6 4.7 4.8 4.9 4.8 4.7 540  |  55 4.3 4.7 4.6 4.8 4.8 4.7 4.8 4.7 4.8 4.9 550  |  56 4.6 4.6 4.6 4.8 4.5 4.6 4.7 4.8 4.6 4.6 560  |  57 4.5 4.6 4.8 4.7 4.6 4.8 4.7 4.5 4.7 4.8 570  |  58 4.9 4.6 4.7 4.2 4.7 4.7 4.7 4.8 4.6 4.7 580  |  59 4.8 4.7 4.6 4.6 4.7 4.6 4.5 4.5 4.7 4.6 590  |  60 4.9 4.6 4.7 4.9 4.8 4.4 4.7 4.8 4.5 4.5 600  |  61 4.8 4.8 4.7 4.1 4.8 4.8 4.7 4.8 4.7 4.7 610  |  62 4.8 4.8 4.8 4.7 4.8 4.6 4.6 4.5 4.4 4.7 620  |  63 4.8 4.8 4.8 4.2 4.8 4.4 4.7 4.8 4.7 4.7 630  |  64 4.8 4.8 4 4.6 4.5 4.8 4.8 4.6 4.8 4.6 640  |  65 4.4 4.5 4.9 4.6 4.4 4.5 4.8 4.7 4.5 4.8 650  |  66 4.8 4.7 4.6 4.7 4.8 4.7 4.3 4.9 4.6 4.6 660  |  67 4.7 4.7 4.7 4.8 4.8 4.7 4.8 4.8 4.9 4.7 670  |  68 4.6 4.7 4.8 4.8 4.6 4.7 4.4 4.7 4.3 4.6 680  |  69 4.9 4.7 4.7 4.8 4.7 4.8 4.8 4.9 4.8 4.7 690  |  70 4.6 4.7 4.5 4.6 4.7 4.8 4.7 4.6 4.6 4.2 700  |  71 4.6 4.7 4.8 4.8 4.8 4.8 4.7 4.9 4.6 4.8 710  |  72 4.8 4.6 4.7 4.8 4.8 4.5 4.6 4.7 4.7 4.5 720  |  73 4.6 4.8 4.7 4.7 4.7 4.8 4.9 4.8 4.8 4.8 730  |  74 4.9 4.9 4.7 4.8 4.8 4.8 4.9 4.4 4.9 4.7 740  |  75 4.5 4.6 4.6 4.8 4.8 4.6 4.4 4.8 4.7 4.8 750  |  76 4.7 4.7 4.8 4.6 4.5 4.8 4.7 4.5 4.7 4.6 760  |  77 4.7 4.5 4.8 4.5 4.6 4.8 4.8 4.8 4.7 4.6 770  |  78 4.7 4.7 4.7 3.9 4.5 4.7 4.6 4.7 4.4 4.9 780  |  79 4.5 4.8 None 3.9 4.7 4.7 4.3 4.8 4.8 4. ...

# %%
df['course_rating']= count

# %%
# course difficulty type
count=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    for j in range(0,10):
        cd= soup.find_all('span',class_='difficulty')[j].get_text()
        count.append(cd)
    print(len(count), end='\t|\t')
# Out:
# 1 10	|	2 20	|	3 30	|	4 40	|	5 50	|	6 60	|	7 70	|	8 80	|	9 90	|	10 100	|	11 110	|	12 120	|	13 130	|	14 140	|	15 150	|	16 160	|	17 170	|	18 180	|	19 190	|	20 200	|	21 210	|	22 220	|	23 230	|	24 240	|	25 250	|	26 260	|	27 270	|	28 280	|	29 290	|	30 300	|	31 310	|	32 320	|	33 330	|	34 340	|	35 350	|	36 360	|	37 370	|	38 380	|	39 390	|	40 400	|	41 410	|	42 420	|	43 430	|	44 440	|	45 450	|	46 460	|	47 470	|	48 480	|	49 490	|	50 500	|	51 510	|	52 520	|	53 530	|	54 540	|	55 550	|	56 560	|	57 570	|	58 580	|	59 590	|	60 600	|	61 610	|	62 620	|	63 630	|	64 640	|	65 650	|	66 660	|	67 670	|	68 680	|	69 690	|	70 700	|	71 710	|	72 720	|	73 730	|	74 740	|	75 750	|	76 760	|	77 770	|	78 780	|	79 790	|	80 800	|	81 810	|	82 820	|	83 830	|	84 840	|	85 850	|	86 860	|	87 870	|	88 880	|	89 890	|	90 900	|	91 910	|	92 920	|	93 930	|	94 940	|	95 950	|	96 960	|	97 970	|	98 980	|	99 990	|

# %%
df['course_difficulty']= count

# %%
#course enrollment number
count=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    for j in range(0,10):
        ce=soup.find_all('div', class_ = "rating-enroll-wrapper")[j]
        xe_div=ce.find('span',class_='enrollment-number')
        if xe_div is None:
            print("None",end=' ')
            count.append("None")
        else:        
            print(xe_div.get_text(),end=' ')
            count.append(xe_div.get_text())
    print(len(count))
# Out:
# 1 610k 640k 410k 2m 890k 250k 3.6m 430k 430k 170k 10
# 2 350k 290k 420k 3m 490k 420k 560k 420k 240k 1,000k 20
# 3 470k 330k 900k 110k 500k 50k 460k 310k 400k 110k 30
# 4 290k 410k 400k 470k 400k 200k 170k None 320k 460k 40
# 5 560k 710k 180k 640k 130k 160k None 100k 330k 5.9k 50
# 6 940k 180k 560k 230k 450k 510k 1.8m 180k 170k 220k 60
# 7 410k 250k 210k 130k 120k 530k 210k 120k 140k 110k 70
# 8 210k 280k 920k 170k 140k 120k 670k 130k 37k 810k 80
# 9 240k None 72k 150k 41k 43k 18k 11k 170k 900k 90
# 10 270k 350k 270k 410k 27k 170k 410k 97k 310k 160k 100
# 11 240k 110k 110k 180k 450k 97k 28k 380k 950k 240k 110
# 12 360k 140k 89k 100k 410k 64k 120k 130k 23k 300k 120
# 13 210k 55k 230k 43k 270k 180k 110k 67k 400k 110k 130
# 14 2.5m 83k 360k 9.5k 31k 150k 630k 130k 6.8k 160k 140
# 15 270k 98k 210k 130k 210k 190k 28k 42k 81k 330k 150
# 16 610k 88k 160k 64k 340k 25k 190k 86k 49k 45k 160
# 17 62k 82k 12k 94k 18k 98k 120k 330k 27k 420k 170
# 18 140k 39k 270k 37k 98k 25k 59k 140k 110k 37k 180
# 19 30k 110k 170k 130k 250k 26k 220k 170k 47k 23k 190
# 20 220k 75k 260k 21k 250k 100k 160k 68k 200k 120k 200
# 21 120k 170k 18k 34k 39k 13k 190k 520k 290k 28k 210
# 22 25k 160k 110k 280k 37k 1.1m 100k 160k 110k 490k 220
# 23 290k 300k 200k 56k 360k 390k 240k 44k 160k 49k 230
# 24 27k 25k 32k 140k 73k 83k 29k 210k 47k 290k 240
# 25 210k 51k 370k 120k 23k 71k 430k 93k 75k 60k 250
# 26 67k 74k 540k 48k 320k 7.9k 55k 310k 69k 90k 260
# 27 58k 84k 6.2k 160k 60k 72k 54k 50k 220k 120k 270
# 28 33k 290k 40k 89k 130k None 120k 4.3k 71k 3.2k 280
# 29 210k 99k 350k 23k 120k 220k 120k 32k 2.7k 66k 290
# 30 110k 81k 40k 410k 110k 86k 200k 81k 250k 51k 300
# 31 86k 97k 440k 4.9k 5.3k 41k 20k 18k 220k None 310
# 32 16k 88k 8.9k 91k 95k 59k 99k 360k 280k 41k 320
# 33 120k 22k 150k 57k 29k 12k 20k 82k 140k 38k 330
# 34 32k 160k 69k 31k 160k 230k 86k 36k 140k 200k 340
# 35 61k 15k 27k 84k 340k 340k 19k 31k 47k 34k 350
# 36 32k 100k 300k 150k 71k 52k 4.6k 110k 220k 120k 360
# 37 370k 140k 39k 54k 83k 85k 110k 42k 6.6k 250k 370
# 38 140k 190k 10k 110k 160k 610k 160k 52k 22k 11k 380
# 39 5.4k 7.8k 67k 840k 42k None 51k 37k 36k 44k 390
# 40 550k 95k 32k 99k 140k 14k 18k 100k 3.9k 35k 400
# 41 57k 17k 190k 69k 94k 200k 74k 170k 82k 530k 410
# 42 29k 36k 96k 93k 12k 51k 28k 76k 110k 57k 420
# 43 160k 82k 20k 88k 19k 150k 95k 35k 46k 140k 430
# 44 56k 6.3k 24k 81k 92k 24k 130k 60k 16k 7.8k 440
# 45 110k 210k 95k 21k 40k 90k 320k 9.1k 96k 350k 450
# 46 150k 61k 38k 140k 200k 60k 32k 18k 25k 97k 460
# 47 220k 62k 42k 11k 27k 300k 270k 63k 40k 41k 470
# 48 16k 34k 110k 8k 59k 160k 12k 150k 38k 65k 480
# 49 59k 51k 7.8k 17k 37k 62k 40k 10k 54k 22k 490
# 50 120k 70k 26k 14k 110k 55k 16k 52k 41k 45k 500
# 51 63k 16k 47k 24k 80k 99k 9k 170k 19k 4.8k 510
# 52 110k 46k 29k 16k 6.4k 120k 36k 67k 8.7k 14k 520
# 53 2.4k 40k 130k 44k 84k 140k 28k 160k 42k 34k 530
# 54 93k 140k 48k 28k 220k 78k 8.8k 7.8k None 8.3k 540
# 55 9.8k 85k 140k 89k 11k 20k 55k 8.7k 45k 8.6k 550
# 56 35k 320k 140k 28k 180k 210k 39k 50k 3.6k 39k 560
# 57 120k 58k 120k 66k 130k 140k 72k 90k 12k 6.8k 570
# 58 100k 59k 19k 82k 20k 40k 53k 65k 88k 22k 580
# 59 86k 7.5k 80k 75k 95k 85k 12k 13k 19k 7.9k 590
# 60 130k 120k 8.6k 9.7k 11k 33k 40k 12k 14k 35k 600
# 61 34k 20k 110k 20k 33k 170k 86k 51k 20k 120k 610
# 62 19k 180k 18k 26k 71k 14k 60k 110k 11k 16k 620
# 63 1.7k 1.9k 60k 37k 28k 36k 6k 89k 49k 18k 630
# 64 22k 13k 5.7k 270k 77k 28k 180k 130k 16k 77k 640
# 65 140k 10k 90k 23k 55k 76k 3.9k 110k 8.3k 9.1k 650
# 66 190k 32k 95k 120k 200k 55k 5.4k 23k 69k 130k 660
# 67 11k 53k 73k 300k 54k 100k 24k 14k 8.1k 22k 670
# 68 19k 25k 150k 93k 110k 60k 5.2k 5.1k 100k 57k 680
# 69 6.9k 370k 150k 110k 37k 360k 240k 35k 78k 92k 690
# 70 13k 90k 5.2k 12k 8.1k 51k 30k 16k 79k 300k 700
# 71 200k 45k 23k 65k 60k 19k 160k 1.6k 110k 180k 710
# 72 5.6k 30k 10k 18k 99k 5.2k 27k 36k None 100k 720
# 73 25k 23k 170k 6.4k 20k 5.5k 44k 120k 23k 46k 730
# 74 130k 25k 47k 26k 91k 26k 19k 22k 24k 96k 740
# 75 81k 250k 43k 50k 13k 47k 33k 140k 30k 54k 750
# 76 17k 73k 39k 52k 54k 28k 80k 27k 24k 41k 760
# 77 12k 9.2k 53k 33k 240k 8.7k 54k 42k 57k 110k 770
# 78 6.8k 26k 68k 17k 10k 38k 84k 21k 11k 100k 780
# 79 86k 37k None 84k 72k 80k 16k 50k 36k 57k 790
# 80 110k 32k 11k 33k 17k 25k 37k 17k 16k 150k 800
# 81 120k 50k 12k 16k 33k 73k 27k 27k 25k 84k 810
# 82 15k 65k 130k 12k 23k None 17k 46k 39k 16k 820
# 83 40k 240k 130k 79k 6.9k 18k 30k 7.8k 46k 14k 830
# 84 100k 19k 34k 19k 1.9k 53k 9.4k 80k 60k 9.6k 840
# 85 15k 100k 47k 32k 47k 75k 160k 40k 83k 42k 850
# 86 96k 83k 99k 52k 33k 76k 31k 25k 30k 46k 860
# 87 8.9k 72k 17k 43k 26k 200k 91k 22k 16k 28k 870
# 88 84k 62k 86k 49k 38k 77k 12k 12k 91k 33k 880
# 89 29k 120k 23k 17k 18k 220k 43k 15k 180k 4.9k 890
# 90 93k 24k 75k 1.6k 24k 23k 90k 16k 45k 94k 900
# 91 30k 12k 14k 20k 20k 22k 46k 130k 64k 30k 910
# 92 72k 72k 6.7k 17k 5.1k 63k 89k 16k 85k 42k 920
# 93 37k 53k 32k 6.4k 13k 10k 75k 46k 54k None 930
# 94 3.3k 18k 13k 20k 78k 41k 6k 45k 54k 55k 940
# 95 35k 16k 16k 7.1k 310k 27k 56k 5.3k 68k 7.7k 950
# 96 120k 69k 37k 27k 2.1k 22k 43k 21k 5.4k 82k 960
# 97 13k 4.2k 34k 71k 19k 41k 180k 5.6k 43k 28k 970
# 98 32k 30k 20k 12k 49k 11k 75k 25k 4.7k 150k 980
# 99 130k 7.9k 22k 34k 33k 16k 41k 29k 39k 17k 990

# %%
df['course_enrolled']= count

# %%
# course image URL and Name
count1=[]
count2=[]
for page in range(1,100):
    print(page,end=' ')
    url = "https://www.coursera.org/courses?page="+str(page)+"&index=prod_all_products_term_optimization"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    for j in range(0,10):
        x_div = soup.find_all('img', class_ ="product-photo")[j]
        count1.append(x_div.get('src'))
        count2.append(x_div.get('alt'))
    print(len(count1),end='  ')
    print(len(count2),end='   |   ')
# Out:
# 1 10  10   |   2 20  20   |   3 30  30   |   4 40  40   |   5 50  50   |   6 60  60   |   7 70  70   |   8 80  80   |   9 90  90   |   10 100  100   |   11 110  110   |   12 120  120   |   13 130  130   |   14 140  140   |   15 150  150   |   16 160  160   |   17 170  170   |   18 180  180   |   19 190  190   |   20 200  200   |   21 210  210   |   22 220  220   |   23 230  230   |   24 240  240   |   25 250  250   |   26 260  260   |   27 270  270   |   28 280  280   |   29 290  290   |   30 300  300   |   31 310  310   |   32 320  320   |   33 330  330   |   34 340  340   |   35 350  350   |   36 360  360   |   37 370  370   |   38 380  380   |   39 390  390   |   40 400  400   |   41 410  410   |   42 420  420   |   43 430  430   |   44 440  440   |   45 450  450   |   46 460  460   |   47 470  470   |   48 480  480   |   49 490  490   |   50 500  500   |   51 510  510   |   52 520  520   |   53 530  530   |   54 540  540   |   55 550  550   |   56 560  560   |   57 570  570   |   58 580  580   |   59 590  590   |   60 600  600   |   61 610  610   |   62 620  620   |   63 630  630   |   64 640  640   |   65 650  650   |   66 660  660   |   67 670  670   |   68 680  680   |   69 690  690   |   70 700  700   |   71 710  710   |   72 720  720   |   73 730  730   |   74 740  740   |   75 750  750   |   76 760  760   |   77 770  770   |   78 780  780   |   79 790  790   |   80 800  800   |   81 810  810   |   82 820  820   |   83 830  830   |   84 840  840   |   85 850  850   |   86 860  860   |   87 870  870   |   88 880  880   |   89 890  890   |   90 900  900   |   91 910  910   |   92 920  920   |   93 930  930   |   94 940  940   |   95 950  950   |   96 960  960   |   97 970  970   |   98 980  980   |   99 990  990   |

# %%
df['course_imageURL']=count1
df['course_imagename']=count2

# %%
print(df.head())
# Out:
#                    course_title  \
# 0             Google IT Support
# 1              IBM Data Science
# 2  Introduction to Data Science
# 3          Python for Everybody
# 4                 Deep Learning
#
#                                           course_URL     course_organization  \
# 0  https://www.coursera.org/professional-certific...                  Google
# 1  https://www.coursera.org/professional-certific...                     IBM
# 2  https://www.coursera.org/specializations/intro...                     IBM
# 3    https://www.coursera.org/specializations/python  University of Michigan
# 4  https://www.coursera.org/specializations/deep-...         deeplearning.ai
#
#     course_certificate_type course_rating course_difficulty course_enrolled  \
# 0  PROFESSIONAL CERTIFICATE           4.8          Beginner            610k
# 1  PROFESSIONAL CERTIFICATE           4.6          Beginner            640k
# 2            SPECIALIZATION           4.6          Beginner            410k
# 3            SPECIALIZATION           4.8          Beginner              2m
# 4            SPECIALIZATION           4.8      Intermediate            890k
#
#                                      course_imageURL  \
# 0  https://d3njjcbhbojbot.cloudfront.net/api/util...
# 1  https://d3njjcbhbojbot.cloudfront.net/api/util...
# 2  https://d3njjcbhbojbot.cloudfront.net/api/util...
# 3  https://d3njjcbhbojbot.cloudfront.net/api/util...
# 4  https://d3njjcbhbojbot.cloudfront.net/api/util...
#
#                                  course_imagename
# 0                     Google IT Support by Google
# 1                         IBM Data Science by IBM
# 2             Introduction to Data Science by IBM
# 3  Python for Everybody by University of Michigan
# 4                Deep Learning by deeplearning.ai

# %% [markdown]
# # ENd

# %%
for i in range(0,10):
    cu= soup.find_all("a", class_='rc-DesktopSearchCard anchor-wrapper')[i]
    course_URL.append("https://www.coursera.org/"+ cu.get('href'))

# %%
print(course_URL)
# Out:
# ['https://www.coursera.org//professional-certificates/google-it-support', 'https://www.coursera.org//professional-certificates/ibm-data-science', 'https://www.coursera.org//specializations/introduction-data-science', 'https://www.coursera.org//specializations/python', 'https://www.coursera.org//specializations/deep-learning', 'https://www.coursera.org//professional-certificates/google-it-automation', 'https://www.coursera.org//learn/machine-learning', 'https://www.coursera.org//specializations/key-technologies-for-business', 'https://www.coursera.org//specializations/ibm-ai-foundations-for-business', 'https://www.coursera.org//learn/indigenous-canada']

# %%
course_Certificate_type = []
for j in range(0,10):
    cc= soup.find_all('div', class_='_jen3vs _1d8rgfy3')[j].get_text()
    course_Certificate_type.append(cc)

# %%
print(course_Certificate_type)
# Out:
# ['PROFESSIONAL CERTIFICATE', 'PROFESSIONAL CERTIFICATE', 'SPECIALIZATION', 'SPECIALIZATION', 'SPECIALIZATION', 'PROFESSIONAL CERTIFICATE', 'COURSE', 'SPECIALIZATION', 'SPECIALIZATION', 'COURSE']

# %%
for j in range(0,10):
    cr=soup.find_all('span', class_ = 'ratings-text')[j].get_text()
    course_rating.append(cr)

# %%
print(course_rating)
# Out:
# ['4.8', '4.6', '4.6', '4.8', '4.8', '4.7', '4.9', '4.7', '4.7', '4.8']

# %%
course_difficulty = []
for j in range(0,10):
    x= soup.find_all('span',class_='difficulty')[j].get_text()
    course_difficulty.append(x)

# %%
print(course_difficulty)
# Out:
# ['Beginner', 'Beginner', 'Beginner', 'Beginner', 'Intermediate', 'Beginner', 'Mixed', 'Beginner', 'Beginner', 'Mixed']

# %%
course_students_enrolled = []
for j in range(0,10):
    x= soup.find_all('span',class_='enrollment-number')[j].get_text()
    course_students_enrolled.append(x)

# %%
print(course_students_enrolled)
# Out:
# ['610k', '640k', '410k', '2m', '890k', '250k', '3.6m', '430k', '430k', '170k']

# %%
course_image_URL = []
course_image_name=[]
for j in range(0,10):
    x_div = soup.find_all('img', class_ ="product-photo")[j]
#div class="image-wrapper"
# print(x_div.get('src'))
# print(x_div.get('alt'))
    course_image_URL.append(x_div.get('src'))
    course_image_name.append(x_div.get('alt'))

# %%
print(course_image_URL,course_image_name)
# Out:
# ['https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/14/b2d530f1ad11e7ab380fc0c6c817a8/Search-Thumbnail.jpg?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/ed/4131809fe511e8937a7926bc59e37f/Professional-Certificate---Data-Science---600x600---Blu-Text.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/32/d719a2d0d946d59e1151bc10ec29f5/Specialization-Certificate-Emblem---IDS---600x600.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d2j5ihb19pt1hq.cloudfront.net/sdp_page/s12n_logos/python.jpg?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/57/4be3fd8d16487ab9cfa7bba909b236/GreyLogoName1000x1000.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/10/94e64625eb4b41b05e66ed0e5bab30/Xavier-MI-Thompson-119.jpg?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera/topics/ml/large-icon.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/93/1543b8c7d64dad864ca79e876a065d/Key-Technology-Foundations-1-.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bb/a0b5642d924caabb6101aa7e1afa66/IBM-AI-Foundations-for-Business.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF', 'https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera-course-photos/35/01fcc0dd0011e6bfe6e9e792d574eb/Logo.png?auto=format%2Ccompress&dpr=1&w=150&h=150&fit=fill&bg=FFF'] ['Google IT Support by Google', 'IBM Data Science by IBM', 'Introduction to Data Science by IBM', 'Python for Everybody by University of Michigan', 'Deep Learning by deeplearning.ai', 'Google IT Automation with Python by Google', 'Machine Learning by Stanford University', 'Key Technologies for Business by IBM', 'IBM AI Foundations for Business by IBM', 'Indigenous Canada by University of Alberta']

# %%
# Out:
# <div class="ais-InfiniteHits" data-reactid="1472">
#  <ul class="ais-InfiniteHits-list" data-reactid="1473">
#   <li class="ais-InfiniteHits-item" data-reactid="1474">
#    <div data-reactid="1475">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":0,"href":"/professional-certificates/google-it-support","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~7lHCSlFIEeeffRIHljDI_g","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1476" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/professional-certificates/google-it-support" data-track-page="search" href="/professional-certificates/google-it-support" to="/professional-certificates/google-it-support">
#      <div data-reactid="1477">
#       <div class="vertical-box" data-reactid="1478">
#        <div class="card-content" data-reactid="1479">
#         <div class="image-wrapper" data-reactid="1480">
#          <img alt="Google IT Support by Google" class="product-photo" data-reactid="1481" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/14/b2d530f1ad11e7ab380fc0c6c817a8/Search-Thumbnail.jpg?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/14/b2d530f1ad11e7ab380fc0c6c817a8/Search-Thumbnail.jpg?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/14/b2d530f1ad11e7ab380fc0c6c817a8/Search-Thumbnail.jpg?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1482">
#          <div class="horizontal-box" data-reactid="1483">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1484">
#            Google IT Support
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1485">
#           <span class="partner-name m-b-1s" data-reactid="1486">
#            Google
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1487">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1488">
#            PROFESSIONAL CERTIFICATE
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1489">
#           <div class="rating-enroll-wrapper" data-reactid="1490">
#            <div class="info-item" data-reactid="1491">
#             <div class="rc-Ratings horizontal-box" data-reactid="1492">
#              <div class="ratings-icon" data-reactid="1493">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1494">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1495">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1496">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1497">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1498">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1499">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1500">
#               Rated 4.8 out of five stars. 62639 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1501">
#               4.8
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1502">
#               <!-- react-text: 1503 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1504">
#                62,639
#               </span>
#               <!-- react-text: 1505 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1506">
#             <span data-reactid="1507">
#              <span class="enrollment-number" data-reactid="1508">
#               610k
#              </span>
#              <!-- react-text: 1509 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1510">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1511" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1512" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1513" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1514">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1515" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1516">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1517">
#    <div data-reactid="1518">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":1,"href":"/professional-certificates/ibm-data-science","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~dwzq23ZLEei12goo904QNg","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1519" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/professional-certificates/ibm-data-science" data-track-page="search" href="/professional-certificates/ibm-data-science" to="/professional-certificates/ibm-data-science">
#      <div data-reactid="1520">
#       <div class="vertical-box" data-reactid="1521">
#        <div class="card-content" data-reactid="1522">
#         <div class="image-wrapper" data-reactid="1523">
#          <img alt="IBM Data Science by IBM" class="product-photo" data-reactid="1524" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/ed/4131809fe511e8937a7926bc59e37f/Professional-Certificate---Data-Science---600x600---Blu-Text.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/ed/4131809fe511e8937a7926bc59e37f/Professional-Certificate---Data-Science---600x600---Blu-Text.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/ed/4131809fe511e8937a7926bc59e37f/Professional-Certificate---Data-Science---600x600---Blu-Text.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1525">
#          <div class="horizontal-box" data-reactid="1526">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1527">
#            IBM Data Science
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1528">
#           <span class="partner-name m-b-1s" data-reactid="1529">
#            IBM
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1530">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1531">
#            PROFESSIONAL CERTIFICATE
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1532">
#           <div class="rating-enroll-wrapper" data-reactid="1533">
#            <div class="info-item" data-reactid="1534">
#             <div class="rc-Ratings horizontal-box" data-reactid="1535">
#              <div class="ratings-icon" data-reactid="1536">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1537">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1538">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1539">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1540">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1541">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1542">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1543">
#               Rated 4.6 out of five stars. 62928 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1544">
#               4.6
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1545">
#               <!-- react-text: 1546 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1547">
#                62,928
#               </span>
#               <!-- react-text: 1548 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1549">
#             <span data-reactid="1550">
#              <span class="enrollment-number" data-reactid="1551">
#               640k
#              </span>
#              <!-- react-text: 1552 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1553">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1554" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1555" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1556" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1557">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1558" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1559">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1560">
#    <div data-reactid="1561">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":2,"href":"/specializations/introduction-data-science","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~_Fk2Gi3cEeiHghIydZ_0lA","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1562" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/specializations/introduction-data-science" data-track-page="search" href="/specializations/introduction-data-science" to="/specializations/introduction-data-science">
#      <div data-reactid="1563">
#       <div class="vertical-box" data-reactid="1564">
#        <div class="card-content" data-reactid="1565">
#         <div class="image-wrapper" data-reactid="1566">
#          <img alt="Introduction to Data Science by IBM" class="product-photo" data-reactid="1567" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/32/d719a2d0d946d59e1151bc10ec29f5/Specialization-Certificate-Emblem---IDS---600x600.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/32/d719a2d0d946d59e1151bc10ec29f5/Specialization-Certificate-Emblem---IDS---600x600.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/32/d719a2d0d946d59e1151bc10ec29f5/Specialization-Certificate-Emblem---IDS---600x600.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1568">
#          <div class="horizontal-box" data-reactid="1569">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1570">
#            Introduction to Data Science
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1571">
#           <span class="partner-name m-b-1s" data-reactid="1572">
#            IBM
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1573">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1574">
#            SPECIALIZATION
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1575">
#           <div class="rating-enroll-wrapper" data-reactid="1576">
#            <div class="info-item" data-reactid="1577">
#             <div class="rc-Ratings horizontal-box" data-reactid="1578">
#              <div class="ratings-icon" data-reactid="1579">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1580">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1581">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1582">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1583">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1584">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1585">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1586">
#               Rated 4.6 out of five stars. 48311 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1587">
#               4.6
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1588">
#               <!-- react-text: 1589 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1590">
#                48,311
#               </span>
#               <!-- react-text: 1591 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1592">
#             <span data-reactid="1593">
#              <span class="enrollment-number" data-reactid="1594">
#               410k
#              </span>
#              <!-- react-text: 1595 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1596">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1597" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1598" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1599" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1600">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1601" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1602">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1603">
#    <div data-reactid="1604">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":3,"href":"/specializations/python","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~F-h1g0w7EeWeOApO_l5R1w","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1605" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/specializations/python" data-track-page="search" href="/specializations/python" to="/specializations/python">
#      <div data-reactid="1606">
#       <div class="vertical-box" data-reactid="1607">
#        <div class="card-content" data-reactid="1608">
#         <div class="image-wrapper" data-reactid="1609">
#          <img alt="Python for Everybody by University of Michigan" class="product-photo" data-reactid="1610" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d2j5ihb19pt1hq.cloudfront.net/sdp_page/s12n_logos/python.jpg?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d2j5ihb19pt1hq.cloudfront.net/sdp_page/s12n_logos/python.jpg?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d2j5ihb19pt1hq.cloudfront.net/sdp_page/s12n_logos/python.jpg?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1611">
#          <div class="horizontal-box" data-reactid="1612">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1613">
#            Python for Everybody
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1614">
#           <span class="partner-name m-b-1s" data-reactid="1615">
#            University of Michigan
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1616">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1617">
#            SPECIALIZATION
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1618">
#           <div class="rating-enroll-wrapper" data-reactid="1619">
#            <div class="info-item" data-reactid="1620">
#             <div class="rc-Ratings horizontal-box" data-reactid="1621">
#              <div class="ratings-icon" data-reactid="1622">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1623">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1624">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1625">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1626">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1627">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1628">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1629">
#               Rated 4.8 out of five stars. 193349 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1630">
#               4.8
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1631">
#               <!-- react-text: 1632 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1633">
#                193,349
#               </span>
#               <!-- react-text: 1634 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1635">
#             <span data-reactid="1636">
#              <span class="enrollment-number" data-reactid="1637">
#               2m
#              </span>
#              <!-- react-text: 1638 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1639">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1640" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1641" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1642" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1643">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1644" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1645">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1646">
#    <div data-reactid="1647">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":4,"href":"/specializations/deep-learning","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~W62RsyrdEeeFQQqyuQaohA","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1648" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/specializations/deep-learning" data-track-page="search" href="/specializations/deep-learning" to="/specializations/deep-learning">
#      <div data-reactid="1649">
#       <div class="vertical-box" data-reactid="1650">
#        <div class="card-content" data-reactid="1651">
#         <div class="image-wrapper" data-reactid="1652">
#          <img alt="Deep Learning by deeplearning.ai" class="product-photo" data-reactid="1653" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/57/4be3fd8d16487ab9cfa7bba909b236/GreyLogoName1000x1000.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/57/4be3fd8d16487ab9cfa7bba909b236/GreyLogoName1000x1000.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/57/4be3fd8d16487ab9cfa7bba909b236/GreyLogoName1000x1000.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1654">
#          <div class="horizontal-box" data-reactid="1655">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1656">
#            Deep Learning
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1657">
#           <span class="partner-name m-b-1s" data-reactid="1658">
#            deeplearning.ai
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1659">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1660">
#            SPECIALIZATION
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1661">
#           <div class="rating-enroll-wrapper" data-reactid="1662">
#            <div class="info-item" data-reactid="1663">
#             <div class="rc-Ratings horizontal-box" data-reactid="1664">
#              <div class="ratings-icon" data-reactid="1665">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1666">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1667">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1668">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1669">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1670">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1671">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1672">
#               Rated 4.8 out of five stars. 109522 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1673">
#               4.8
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1674">
#               <!-- react-text: 1675 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1676">
#                109,522
#               </span>
#               <!-- react-text: 1677 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1678">
#             <span data-reactid="1679">
#              <span class="enrollment-number" data-reactid="1680">
#               890k
#              </span>
#              <!-- react-text: 1681 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1682">
#            <svg aria-labelledby="IntermediateLeveldefault IntermediateLeveldefaultDesc" class="_ufjrdd" data-reactid="1683" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1684" id="IntermediateLeveldefault">
#              Intermediate Level
#             </title>
#             <g data-reactid="1685" fill-rule="nonzero" role="presentation">
#              <path d="M5 29h10v14H5zM19 19h10v24H19z" data-reactid="1686">
#              </path>
#              <path d="M34 5h10v38H34z" data-reactid="1687" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1688">
#             Intermediate
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1689">
#    <div data-reactid="1690">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":5,"href":"/professional-certificates/google-it-automation","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~7_nEU3iaEeiVXgoT1iWlYg","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1691" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/professional-certificates/google-it-automation" data-track-page="search" href="/professional-certificates/google-it-automation" to="/professional-certificates/google-it-automation">
#      <div data-reactid="1692">
#       <div class="vertical-box" data-reactid="1693">
#        <div class="card-content" data-reactid="1694">
#         <div class="image-wrapper" data-reactid="1695">
#          <img alt="Google IT Automation with Python by Google" class="product-photo" data-reactid="1696" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/10/94e64625eb4b41b05e66ed0e5bab30/Xavier-MI-Thompson-119.jpg?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/10/94e64625eb4b41b05e66ed0e5bab30/Xavier-MI-Thompson-119.jpg?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/10/94e64625eb4b41b05e66ed0e5bab30/Xavier-MI-Thompson-119.jpg?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1697">
#          <div class="horizontal-box" data-reactid="1698">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1699">
#            Google IT Automation with Python
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1700">
#           <span class="partner-name m-b-1s" data-reactid="1701">
#            Google
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1702">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1703">
#            PROFESSIONAL CERTIFICATE
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1704">
#           <div class="rating-enroll-wrapper" data-reactid="1705">
#            <div class="info-item" data-reactid="1706">
#             <div class="rc-Ratings horizontal-box" data-reactid="1707">
#              <div class="ratings-icon" data-reactid="1708">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1709">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1710">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1711">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1712">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1713">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1714">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1715">
#               Rated 4.7 out of five stars. 13794 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1716">
#               4.7
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1717">
#               <!-- react-text: 1718 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1719">
#                13,794
#               </span>
#               <!-- react-text: 1720 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1721">
#             <span data-reactid="1722">
#              <span class="enrollment-number" data-reactid="1723">
#               250k
#              </span>
#              <!-- react-text: 1724 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1725">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1726" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1727" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1728" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1729">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1730" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1731">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1732">
#    <div data-reactid="1733">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":6,"href":"/learn/machine-learning","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"course~Gtv4Xb1-EeS-ViIACwYKVQ","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1734" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/learn/machine-learning" data-track-page="search" href="/learn/machine-learning" to="/learn/machine-learning">
#      <div data-reactid="1735">
#       <div class="vertical-box" data-reactid="1736">
#        <div class="card-content" data-reactid="1737">
#         <div class="image-wrapper" data-reactid="1738">
#          <img alt="Machine Learning by Stanford University" class="product-photo" data-reactid="1739" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera/topics/ml/large-icon.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera/topics/ml/large-icon.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera/topics/ml/large-icon.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1740">
#          <div class="horizontal-box" data-reactid="1741">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1742">
#            Machine Learning
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1743">
#           <span class="partner-name m-b-1s" data-reactid="1744">
#            Stanford University
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1745">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1746">
#            COURSE
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1747">
#           <div class="rating-enroll-wrapper" data-reactid="1748">
#            <div class="info-item" data-reactid="1749">
#             <div class="rc-Ratings horizontal-box" data-reactid="1750">
#              <div class="ratings-icon" data-reactid="1751">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1752">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1753">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1754">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1755">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1756">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1757">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1758">
#               Rated 4.9 out of five stars. 148067 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1759">
#               4.9
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1760">
#               <!-- react-text: 1761 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1762">
#                148,067
#               </span>
#               <!-- react-text: 1763 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1764">
#             <span data-reactid="1765">
#              <span class="enrollment-number" data-reactid="1766">
#               3.6m
#              </span>
#              <!-- react-text: 1767 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1768">
#            <svg aria-labelledby="MixedLeveldefault MixedLeveldefaultDesc" class="_ufjrdd" data-reactid="1769" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1770" id="MixedLeveldefault">
#              Mixed Level
#             </title>
#             <g data-reactid="1771" fill-rule="nonzero" role="presentation">
#              <path d="M5 28h10v15H5zM20 20h10v23H20zM34 5h10v38H34z" data-reactid="1772" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1773">
#             Mixed
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1774">
#    <div data-reactid="1775">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":7,"href":"/specializations/key-technologies-for-business","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~mF13zqpxEeqDdgqb325wdw","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1776" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/specializations/key-technologies-for-business" data-track-page="search" href="/specializations/key-technologies-for-business" to="/specializations/key-technologies-for-business">
#      <div data-reactid="1777">
#       <div class="vertical-box" data-reactid="1778">
#        <div class="card-content" data-reactid="1779">
#         <div class="image-wrapper" data-reactid="1780">
#          <img alt="Key Technologies for Business by IBM" class="product-photo" data-reactid="1781" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/93/1543b8c7d64dad864ca79e876a065d/Key-Technology-Foundations-1-.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/93/1543b8c7d64dad864ca79e876a065d/Key-Technology-Foundations-1-.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/93/1543b8c7d64dad864ca79e876a065d/Key-Technology-Foundations-1-.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1782">
#          <div class="horizontal-box" data-reactid="1783">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1784">
#            Key Technologies for Business
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1785">
#           <span class="partner-name m-b-1s" data-reactid="1786">
#            IBM
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1787">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1788">
#            SPECIALIZATION
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1789">
#           <div class="rating-enroll-wrapper" data-reactid="1790">
#            <div class="info-item" data-reactid="1791">
#             <div class="rc-Ratings horizontal-box" data-reactid="1792">
#              <div class="ratings-icon" data-reactid="1793">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1794">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1795">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1796">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1797">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1798">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1799">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1800">
#               Rated 4.7 out of five stars. 45353 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1801">
#               4.7
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1802">
#               <!-- react-text: 1803 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1804">
#                45,353
#               </span>
#               <!-- react-text: 1805 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1806">
#             <span data-reactid="1807">
#              <span class="enrollment-number" data-reactid="1808">
#               430k
#              </span>
#              <!-- react-text: 1809 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1810">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1811" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1812" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1813" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1814">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1815" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1816">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1817">
#    <div data-reactid="1818">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":8,"href":"/specializations/ibm-ai-foundations-for-business","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"s12n~zn_b0Y_lEeqE2Q5NANyNFw","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1819" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/specializations/ibm-ai-foundations-for-business" data-track-page="search" href="/specializations/ibm-ai-foundations-for-business" to="/specializations/ibm-ai-foundations-for-business">
#      <div data-reactid="1820">
#       <div class="vertical-box" data-reactid="1821">
#        <div class="card-content" data-reactid="1822">
#         <div class="image-wrapper" data-reactid="1823">
#          <img alt="IBM AI Foundations for Business by IBM" class="product-photo" data-reactid="1824" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bb/a0b5642d924caabb6101aa7e1afa66/IBM-AI-Foundations-for-Business.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bb/a0b5642d924caabb6101aa7e1afa66/IBM-AI-Foundations-for-Business.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://d15cw65ipctsrr.cloudfront.net/bb/a0b5642d924caabb6101aa7e1afa66/IBM-AI-Foundations-for-Business.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1825">
#          <div class="horizontal-box" data-reactid="1826">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1827">
#            IBM AI Foundations for Business
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1828">
#           <span class="partner-name m-b-1s" data-reactid="1829">
#            IBM
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1830">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1831">
#            SPECIALIZATION
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1832">
#           <div class="rating-enroll-wrapper" data-reactid="1833">
#            <div class="info-item" data-reactid="1834">
#             <div class="rc-Ratings horizontal-box" data-reactid="1835">
#              <div class="ratings-icon" data-reactid="1836">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1837">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1838">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1839">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1840">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1841">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1842">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1843">
#               Rated 4.7 out of five stars. 45158 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1844">
#               4.7
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1845">
#               <!-- react-text: 1846 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1847">
#                45,158
#               </span>
#               <!-- react-text: 1848 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1849">
#             <span data-reactid="1850">
#              <span class="enrollment-number" data-reactid="1851">
#               430k
#              </span>
#              <!-- react-text: 1852 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1853">
#            <svg aria-labelledby="BeginnerLeveldefault BeginnerLeveldefaultDesc" class="_ufjrdd" data-reactid="1854" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1855" id="BeginnerLeveldefault">
#              Beginner Level
#             </title>
#             <g data-reactid="1856" fill-rule="nonzero" role="presentation">
#              <path d="M6 30h9v14H6z" data-reactid="1857">
#              </path>
#              <path d="M20 20h9v24h-9zM35 6h9v38h-9z" data-reactid="1858" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1859">
#             Beginner
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#   <li class="ais-InfiniteHits-item" data-reactid="1860">
#    <div data-reactid="1861">
#     <a class="rc-DesktopSearchCard anchor-wrapper" data-click-key="search.search.click.search_card" data-click-value='{"hitPosition":9,"href":"/learn/indigenous-canada","indexName":"prod_all_products_term_optimization","indexPosition":0,"listIndex":1,"namespace":{"action":"click","app":"search","component":"search_card","page":"search"},"noResults":false,"objectID":"course~jYd91UquEeWpQA4vMed_oQ","query":"","queryID":"4368c8dc26cba00b1ec1740e861bcb4c","schema_type":"FRONTEND"}' data-e2e="DesktopSearchCard" data-reactid="1862" data-track="true" data-track-action="click" data-track-app="search" data-track-component="search_card" data-track-href="/learn/indigenous-canada" data-track-page="search" href="/learn/indigenous-canada" to="/learn/indigenous-canada">
#      <div data-reactid="1863">
#       <div class="vertical-box" data-reactid="1864">
#        <div class="card-content" data-reactid="1865">
#         <div class="image-wrapper" data-reactid="1866">
#          <img alt="Indigenous Canada by University of Alberta" class="product-photo" data-reactid="1867" src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera-course-photos/35/01fcc0dd0011e6bfe6e9e792d574eb/Logo.png?auto=format%2Ccompress&amp;dpr=1&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF" srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera-course-photos/35/01fcc0dd0011e6bfe6e9e792d574eb/Logo.png?auto=format%2Ccompress&amp;dpr=2&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://s3.amazonaws.com/coursera-course-photos/35/01fcc0dd0011e6bfe6e9e792d574eb/Logo.png?auto=format%2Ccompress&amp;dpr=3&amp;w=150&amp;h=150&amp;fit=fill&amp;bg=FFF 3x" style="max-width:150px;max-height:150px;"/>
#         </div>
#         <div class="card-info vertical-box" data-reactid="1868">
#          <div class="horizontal-box" data-reactid="1869">
#           <h2 class="color-primary-text card-title headline-1-text" data-reactid="1870">
#            Indigenous Canada
#           </h2>
#          </div>
#          <div class="horizontal-box" data-reactid="1871">
#           <span class="partner-name m-b-1s" data-reactid="1872">
#            University of Alberta
#           </span>
#          </div>
#          <div class="product-type-row horizontal-box" data-reactid="1873">
#           <div class="_jen3vs _1d8rgfy3" data-reactid="1874">
#            COURSE
#           </div>
#          </div>
#          <div class="rc-ProductInfo" data-reactid="1875">
#           <div class="rating-enroll-wrapper" data-reactid="1876">
#            <div class="info-item" data-reactid="1877">
#             <div class="rc-Ratings horizontal-box" data-reactid="1878">
#              <div class="ratings-icon" data-reactid="1879">
#               <div class="rc-CourseRatingIcons small read-only" data-e2e="course-rating" data-reactid="1880">
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1881">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1882">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1883">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star" data-reactid="1884">
#                </i>
#                <i aria-hidden="true" class="c-course-rating-icon cif-icon cif-star-half-empty" data-reactid="1885">
#                </i>
#               </div>
#              </div>
#              <div class="screenreader-only" data-reactid="1886">
#               Rated 4.8 out of five stars. 3592 reviews
#              </div>
#              <span aria-hidden="true" class="ratings-text" data-reactid="1887">
#               4.8
#              </span>
#              <span aria-hidden="true" class="ratings-count" data-reactid="1888">
#               <!-- react-text: 1889 -->
#               (
#               <!-- /react-text -->
#               <span data-reactid="1890">
#                3,592
#               </span>
#               <!-- react-text: 1891 -->
#               )
#               <!-- /react-text -->
#              </span>
#             </div>
#            </div>
#            <div class="enrollment info-item" data-reactid="1892">
#             <span data-reactid="1893">
#              <span class="enrollment-number" data-reactid="1894">
#               170k
#              </span>
#              <!-- react-text: 1895 -->
#              students
#              <!-- /react-text -->
#             </span>
#            </div>
#           </div>
#           <div class="product-difficulty" data-reactid="1896">
#            <svg aria-labelledby="MixedLeveldefault MixedLeveldefaultDesc" class="_ufjrdd" data-reactid="1897" role="img" style="fill:#7E7E7E;height:18px;width:18px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#             <title data-reactid="1898" id="MixedLeveldefault">
#              Mixed Level
#             </title>
#             <g data-reactid="1899" fill-rule="nonzero" role="presentation">
#              <path d="M5 28h10v15H5zM20 20h10v23H20zM34 5h10v38H34z" data-reactid="1900" fill="#D8D8D8">
#              </path>
#             </g>
#            </svg>
#            <span class="difficulty" data-reactid="1901">
#             Mixed
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </a>
#    </div>
#   </li>
#  </ul>
#  <!-- react-empty: 1902 -->
#  <div class="rc-PaginationControls horizontal-box align-items-right large-style" data-e2e="pagination-controls" data-reactid="1903" style="display:flex;justify-content:center;margin-bottom:3rem;margin-top:3rem;">
#   <div aria-label="Page Navigation" class="pagination-controls-container" data-reactid="1904" role="navigation">
#    <button aria-label="Previous Page" class="label-text box arrow arrow-disabled" data-e2e="pagination-controls-prev" data-reactid="1905" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_left_arrow" data-track-page="search" disabled="" type="button">
#     <svg aria-labelledby="ChevronLeftdefault ChevronLeftdefaultDesc" class="_ufjrdd" data-reactid="1906" role="img" style="fill:rgb(255, 255, 255);height:15px;width:15px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#      <title data-reactid="1907" id="ChevronLeftdefault">
#       Chevron Left
#      </title>
#      <g data-reactid="1908" role="presentation" transform="translate(-362.000000, -1749.000000)">
#       <polygon data-reactid="1909" points="376 1773 390.585 1789 391.999 1787.586 378.828 1773 391.999 1758.415 390.585 1757">
#       </polygon>
#      </g>
#     </svg>
#    </button>
#    <button aria-label="Selected page: Page 1" class="box number current" data-e2e="pagination-number-box" data-reactid="1910" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_number_box_1" data-track-page="search" id="pagination_number_box_1" type="button">
#     1
#    </button>
#    <button aria-label="Page 2" class="box number" data-e2e="pagination-number-box" data-reactid="1911" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_number_box_2" data-track-page="search" id="pagination_number_box_2" type="button">
#     2
#    </button>
#    <button aria-label="Page 3" class="box number" data-e2e="pagination-number-box" data-reactid="1912" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_number_box_3" data-track-page="search" id="pagination_number_box_3" type="button">
#     3
#    </button>
#    <button aria-label="Page 4" class="box number" data-e2e="pagination-number-box" data-reactid="1913" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_number_box_4" data-track-page="search" id="pagination_number_box_4" type="button">
#     4
#    </button>
#    <span class="ellipsis" data-reactid="1914">
#     …
#    </span>
#    <button aria-label="Page 100" class="box number" data-e2e="pagination-number-box" data-reactid="1915" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_number_box_100" data-track-page="search" id="pagination_number_box_100" type="button">
#     100
#    </button>
#    <button aria-label="Next Page" class="label-text box arrow" data-e2e="pagination-controls-next" data-reactid="1916" data-track="true" data-track-action="click" data-track-app="search" data-track-component="pagination_right_arrow" data-track-page="search" type="button">
#     <svg aria-labelledby="ChevronRightdefault ChevronRightdefaultDesc" class="_ufjrdd" data-reactid="1917" role="img" style="fill:rgb(255, 255, 255);height:15px;width:15px;" viewbox="0 0 48 48" xmlns="http://www.w3.org/2000/svg">
#      <title data-reactid="1918" id="ChevronRightdefault">
#       Chevron Right
#      </title>
#      <polygon data-reactid="1919" points="16 24 30.585 40 31.999 38.586 18.828 24 31.999 9.415 30.585 8" role="presentation" transform="translate(23.999500, 24.000000) scale(-1, 1) translate(-23.999500, -24.000000)">
#      </polygon>
#     </svg>
#    </button>
#   </div>
#  </div>
#  <div class="rc-CourseQueriesSchemaMarkup" data-reactid="1920">
#   <div data-reactid="1921">
#    <script type="application/ld+json">
#     {"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"https://www.coursera.org/professional-certificates/google-it-support"},{"@type":"ListItem","position":2,"url":"https://www.coursera.org/professional-certificates/ibm-data-science"},{"@type":"ListItem","position":3,"url":"https://www.coursera.org/specializations/introduction-data-science"},{"@type":"ListItem","position":4,"url":"https://www.coursera.org/specializations/python"},{"@type":"ListItem","position":5,"url":"https://www.coursera.org/specializations/deep-learning"},{"@type":"ListItem","position":6,"url":"https://www.coursera.org/professional-certificates/google-it-automation"},{"@type":"ListItem","position":7,"url":"https://www.coursera.org/learn/machine-learning"},{"@type":"ListItem","position":8,"url":"https://www.coursera.org/specializations/key-technologies-for-business"},{"@type":"ListItem","position":9,"url":"https://www.coursera.org/specializations/ibm-ai-foundations-for-business"},{"@type":"ListItem","position":10,"url":"https://www.coursera.org/learn/indigenous-canada"}]}
#    </script>
#   </div>
#  </div>
# </div>
